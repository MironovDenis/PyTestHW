# %% [markdown]
# <a href="https://colab.research.google.com/github/MironovDenis/PyTestHW/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.head(n=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %% [markdown]
# Показать median_house_value где median_income < 2

# %%
df[df['median_income'] < 2]['median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %% [markdown]
# Показать данные в первых 2 столбцах

# %%
df[['longitude', 'longitude']]
# Out:
#        longitude  longitude
# 0        -114.31    -114.31
# 1        -114.47    -114.47
# 2        -114.56    -114.56
# 3        -114.57    -114.57
# 4        -114.57    -114.57
# ...          ...        ...
# 16995    -124.26    -124.26
# 16996    -124.27    -124.27
# 16997    -124.30    -124.30
# 16998    -124.30    -124.30
# 16999    -124.35    -124.35
#
# [17000 rows x 2 columns]

# %% [markdown]
# Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df[(df[ 'housing_median_age'] < 20) & (df[ 'median_house_value'] > 7000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# Определить какое максимальное и минимальное значение median_house_value

# %%
print(df['median_house_value'].max())
# Out:
# 500001.0

# %%
print(df['median_house_value'].min())
# Out:
# 14999.0

# %% [markdown]
# Показать максимальное median_house_value, где median_income = 3.1250

# %%
df[df['median_income'] == 3.1250].median_house_value.max()
# Out:
# 380400.0

# %% [markdown]
# Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
median_house_value_min = df['median_house_value'].min()
df[
    df['median_house_value'] == median_house_value_min
].sort_values(by = 'population', ascending = False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3226     -117.86     34.24                52.0        803.0           267.0
# 568      -117.02     36.40                19.0        619.0           239.0
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16801    -123.17     40.31                36.0         98.0            28.0
#
#        population  households  median_income  median_house_value
# 3226        628.0       225.0         4.1932             14999.0
# 568         490.0       164.0         2.1000             14999.0
# 16643        85.0        38.0         1.6607             14999.0
# 16801        18.0         8.0         0.5360             14999.0

# %% [markdown]
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке
# sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)

# %%
df.loc[(df['population'] < 500) & (df['population'] > 0)].median_house_value.median()
# Out:
# 169500.0

# %% [markdown]
# Задача 42: Узнать какая максимальная households в зоне минимального значения population

# %%
min_pop = df['population'].min()
df[
    df['population'] == min_pop
].households.max()
# Out:
# 4.0
